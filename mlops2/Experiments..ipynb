# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("diamonds.csv")

# %%
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
data.describe().transpose()
# Out:
#          count         mean          std    min     25%      50%      75%  \
# carat  53940.0     0.797940     0.474011    0.2    0.40     0.70     1.04
# depth  53940.0    61.749405     1.432621   43.0   61.00    61.80    62.50
# table  53940.0    57.457184     2.234491   43.0   56.00    57.00    59.00
# price  53940.0  3932.799722  3989.439738  326.0  950.00  2401.00  5324.25
# x      53940.0     5.731157     1.121761    0.0    4.71     5.70     6.54
# y      53940.0     5.734526     1.142135    0.0    4.72     5.71     6.54
# z      53940.0     3.538734     0.705699    0.0    2.91     3.53     4.04
#
#             max
# carat      5.01
# depth     79.00
# table     95.00
# price  18823.00
# x         10.74
# y         58.90
# z         31.80

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df = data.iloc[:,[0,1,2,3,4,5,7,8,9,6]]

# %%
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50   2757
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61   2757
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56   2757
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74   2757
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64   2757
#
# [53940 rows x 10 columns]

# %%
df.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot:title={'center':'carat'}>,
#         <AxesSubplot:title={'center':'depth'}>,
#         <AxesSubplot:title={'center':'table'}>],
#        [<AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'y'}>,
#         <AxesSubplot:title={'center':'z'}>],
#        [<AxesSubplot:title={'center':'price'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.boxplot(figsize =(15,15))
# Out:
# <AxesSubplot:>

# %%
IQR = data['price'].quantile(0.75) - data['price'].quantile(0.25)
lower_limit = data['price'].quantile(0.25) - (IQR * 1.5)
upper_limit = data['price'].quantile(0.75) + (IQR * 1.5)

# %%
IQR = data["table"].quantile(0.75) - data ["table"].quantile(0.25)
lower_limit = data["table"].quantile(0.25) - (IQR * 1.5)
upper_limit = data["table"].quantile(0.25) - (IQR * 1.5)

# %%
IQR = data["depth"].quantile(0.75) - data ["depth"].quantile(0.25)
lower_limit = data["depth"].quantile(0.25) - (IQR * 1.5)
upper_limit = data["depth"].quantile(0.25) - (IQR * 1.5)

# %%
IQR = data["x"].quantile(0.75) - data ["x"].quantile(0.25)
lower_limit = data["x"].quantile(0.25) - (IQR * 1.5)
upper_limit = data["x"].quantile(0.25) - (IQR * 1.5)

# %%
IQR = data["y"].quantile(0.75) - data ["y"].quantile(0.25)
lower_limit = data["y"].quantile(0.25) - (IQR * 1.5)
upper_limit = data["y"].quantile(0.25) - (IQR * 1.5)

# %%
IQR = data["z"].quantile(0.75) - data ["z"].quantile(0.25)
lower_limit = data["z"].quantile(0.25) - (IQR * 1.5)
upper_limit = data["z"].quantile(0.25) - (IQR * 1.5)

# %%
from feature_engine.outliers import Winsorizer
winsor = Winsorizer(capping_method='iqr', # choose  IQR rule boundaries or gaussian for mean and std
                          tail='both', # cap left, right or both tails 
                          fold=1.5,
                          variables=['price','carat','table','depth','x','y','z'])
df_t = winsor.fit_transform(data[['price','carat','table','depth','x','y','z']])

# %%
# lets see boxplot

sns.boxplot(df_t.price);plt.title('price');plt.show()

sns.boxplot(df_t.carat);plt.title('carat');plt.show()

sns.boxplot(df_t.table);plt.title('table');plt.show()

sns.boxplot(df_t.depth);plt.title('depth');plt.show()

sns.boxplot(df_t.x);plt.title('x');plt.show()

sns.boxplot(df_t.y);plt.title('y');plt.show()

sns.boxplot(df_t.z);plt.title('z');plt.show()

# %%
sns.heatmap(df.iloc[:,:].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(30,20))
sns.pairplot(data,hue='cut', palette='hls')
plt.show()

# %%
plt.scatter(df.carat,df.price,color='blue');plt.xlabel('Carat');plt.ylabel('Price(k$)')
plt.show()

# %%
plt.scatter(df.color,df.price,color='pink');plt.xlabel('color');plt.ylabel('Price(k$)')
plt.show()

# %%
plt.scatter(df.cut,df.price,color='brown');plt.xlabel('cut');plt.ylabel('Price(k$)')
plt.show()

# %%
plt.scatter(df.depth,df.price,color = "yellow");plt.xlabel("depth");plt.ylabel('Price')
plt.show()

# %%
plt.scatter(df.x,df.price,color = "red");plt.xlabel("x");plt.ylabel('Price')
plt.show()

# %%
plt.scatter(df.y,df.price,color = "black");plt.xlabel("y");plt.ylabel('Price')
plt.show()

# %%
plt.scatter(df.z,df.price,color = "orange");plt.xlabel("z");plt.ylabel('Price')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df[["carat","cut","color","clarity","depth","table","x","y","z"]]

# %%
y = df["price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.75, random_state = 0)

# %%
X_train.head()
# Out:
#        carat        cut color clarity  depth  table     x     y     z
# 3558    0.72      Ideal     H    VVS2   61.7   55.0  5.77  5.80  3.57
# 43666   0.50  Very Good     D     SI1   60.8   63.0  5.10  5.13  3.11
# 28687   0.40       Good     F     SI1   63.6   59.0  4.64  4.67  2.96
# 41073   0.41      Ideal     F    VVS2   60.1   57.0  4.85  4.83  2.91
# 33888   0.30      Ideal     E     VS2   62.3   57.0  4.32  4.29  2.68

# %%
X_train.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
X_train_cat = X_train.select_dtypes(include=['object'])

X_train_cat.head()
# Out:
#              cut color clarity
# 3558       Ideal     H    VVS2
# 43666  Very Good     D     SI1
# 28687       Good     F     SI1
# 41073      Ideal     F    VVS2
# 33888      Ideal     E     VS2

# %%
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

# %%
X_train_catg = pd.DataFrame(enc.fit_transform(X_train_cat), 
                                    columns = X_train_cat.columns, 
                                    index = X_train_cat.index)

X_train_catg
# Out:
#        cut  color  clarity
# 3558   2.0    4.0      7.0
# 43666  4.0    0.0      2.0
# 28687  1.0    2.0      2.0
# 41073  2.0    2.0      7.0
# 33888  2.0    1.0      5.0
# ...    ...    ...      ...
# 45891  3.0    2.0      5.0
# 52416  1.0    0.0      2.0
# 42613  3.0    5.0      4.0
# 43567  2.0    3.0      1.0
# 2732   2.0    2.0      3.0
#
# [13485 rows x 3 columns]

# %%
X_train_num = X_train.select_dtypes(include=['int64', 'float64'])

X_train_num.head()
# Out:
#        carat  depth  table     x     y     z
# 3558    0.72   61.7   55.0  5.77  5.80  3.57
# 43666   0.50   60.8   63.0  5.10  5.13  3.11
# 28687   0.40   63.6   59.0  4.64  4.67  2.96
# 41073   0.41   60.1   57.0  4.85  4.83  2.91
# 33888   0.30   62.3   57.0  4.32  4.29  2.68

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


X_train_no = pd.DataFrame(scaler.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

# %%
X_train_rescaled = pd.concat([X_train_catg,X_train_no], axis=1)

X_train_rescaled.head()
# Out:
#        cut  color  clarity     carat     depth     table         x         y  \
# 3558   2.0    4.0      7.0 -0.166778 -0.040055 -1.095039  0.031721  0.054696
# 43666  4.0    0.0      2.0 -0.630629 -0.662654  2.479176 -0.565672 -0.535163
# 28687  1.0    2.0      2.0 -0.841470  1.274322  0.692069 -0.975822 -0.940141
# 41073  2.0    2.0      7.0 -0.820386 -1.146898 -0.201485 -0.788579 -0.799279
# 33888  2.0    1.0      5.0 -1.052311  0.375011 -0.201485 -1.261144 -1.274688
#
#               z
# 3558   0.043966
# 43666 -0.617937
# 28687 -0.833774
# 41073 -0.905720
# 33888 -1.236671

# %%
X_test_cat = X_test.select_dtypes(include=['object'])

X_test_cat.head()
# Out:
#              cut color clarity
# 10176      Ideal     H     SI2
# 16083      Ideal     H     SI1
# 13420    Premium     I     SI1
# 20407      Ideal     F     SI1
# 8909   Very Good     F     VS2

# %%
X_test_catg = pd.DataFrame(enc.transform(X_test_cat), 
                                    columns = X_test_cat.columns, 
                                    index = X_test_cat.index)

# %%
X_test_num = X_test.select_dtypes(include=['int64', 'float64'])

X_test_num.head()
# Out:
#        carat  depth  table     x     y     z
# 10176   1.10   62.0   55.0  6.61  6.65  4.11
# 16083   1.29   62.6   56.0  6.96  6.93  4.35
# 13420   1.20   61.1   58.0  6.88  6.80  4.18
# 20407   1.50   60.9   56.0  7.43  7.36  4.50
# 8909    0.90   61.7   57.0  6.17  6.21  3.82

# %%
X_test_no = pd.DataFrame(scaler.transform(X_test_num), 
                                    columns = X_test_num.columns, 
                                    index = X_test_num.index)

X_test_no.head()
# Out:
#           carat     depth     table         x         y         z
# 10176  0.634418  0.167478 -1.095039  0.780691  0.803025  0.820981
# 16083  1.035017  0.582545 -0.648262  1.092762  1.049533  1.166322
# 13420  0.845260 -0.455121  0.245292  1.021432  0.935083  0.921706
# 20407  1.477783 -0.593476 -0.648262  1.511829  1.428099  1.382159
# 8909   0.212736 -0.040055 -0.201485  0.388374  0.415655  0.403695

# %%
X_test_rescaled = pd.concat([X_test_catg,X_test_no], axis=1)

X_test_rescaled.head()
# Out:
#        cut  color  clarity     carat     depth     table         x         y  \
# 10176  2.0    4.0      3.0  0.634418  0.167478 -1.095039  0.780691  0.803025
# 16083  2.0    4.0      2.0  1.035017  0.582545 -0.648262  1.092762  1.049533
# 13420  3.0    5.0      2.0  0.845260 -0.455121  0.245292  1.021432  0.935083
# 20407  2.0    2.0      2.0  1.477783 -0.593476 -0.648262  1.511829  1.428099
# 8909   4.0    2.0      5.0  0.212736 -0.040055 -0.201485  0.388374  0.415655
#
#               z
# 10176  0.820981
# 16083  1.166322
# 13420  0.921706
# 20407  1.382159
# 8909   0.403695

# %% [markdown]
# # Running the Experiment

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor

from sklearn import metrics

# %%
# !mlflow ui

# %%
import mlflow

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000')
mlflow.set_experiment("Diamond Price Prediction")
# Out:
# 2022/10/04 08:54:00 INFO mlflow.tracking.fluent: Experiment with name 'Diamond Price Prediction' does not exist. Creating a new experiment.
# <Experiment: artifact_location='./mlruns/1', creation_time=1664853840745, experiment_id='1', last_update_time=1664853840745, lifecycle_stage='active', name='Diamond Price Prediction', tags={}>

# %%
from pickle import dump
dump(enc,open('Ordinal_Encoder.pkl','wb'))
dump(scaler, open('Standard_Scaler.pkl', 'wb'))

# %% [markdown]
# # KNN Experiment

# %%
with mlflow.start_run():
    mlflow.set_tag("developer","Ravi Teja")
    mlflow.set_tag("Algorithm","KNN")
    # log the data for each run using log_param, log_metric, log_model
    mlflow.log_param("data-path","diamonds.csv")
    k=21
    mlflow.log_param("n_neighbors",k)
    knn_regressor = KNeighborsRegressor(n_neighbors=k)
    knn_regressor.fit(X_train_rescaled, y_train)
    y_test_pred = knn_regressor.predict(X_test_rescaled)
    MAE=metrics.mean_absolute_error(y_test, y_test_pred)
    mlflow.log_metric("Mean Absolute Error",MAE)
    mlflow.sklearn.log_model(knn_regressor,artifact_path="models")
    mlflow.log_artifact("Standard_scaler.pkl")
    mlflow.log_artifact("Ordinal_Encoder.pkl")

# %% [markdown]
# # RFR Experiment

# %%
with mlflow.start_run():
    mlflow.set_tag("developer","Ravi Teja")
    mlflow.set_tag("Algorithm","RFR")
    # log the data for each run using log_param, log_metric, log_model
    mlflow.log_param("data-path","diamonds.csv")
    d=5
    f='auto'
    l=50
    n=100
    mlflow.log_param("max_depth",k)
    mlflow.log_param("max_features",f)
    mlflow.log_param("max_leaf_nodes",l)
    mlflow.log_param("n_estimators",n)
    rf_regressor =RandomForestRegressor(max_depth=k,max_features=f,max_leaf_nodes=l,n_estimators=n)
    rf_regressor.fit(X_train_rescaled, y_train)
    y_test_pred = rf_regressor.predict(X_test_rescaled)
    MAE=metrics.mean_absolute_error(y_test, y_test_pred)
    mlflow.log_metric("Mean Absolute Error",MAE)
    mlflow.sklearn.log_model(rf_regressor,artifact_path="models")
    mlflow.log_artifact("Standard_scaler.pkl")
    mlflow.log_artifact("Ordinal_Encoder.pkl")

# %% [markdown]
# #  Decision Tree Experiment

# %%
with mlflow.start_run():
    mlflow.set_tag("developer", "Ravi Teja")
    mlflow.set_tag("Algorithm", "DTR")
    # log the data for each run using log_param, log_metric, log_model
    mlflow.log_param("data-path", "diamonds.csv")
    d=5
    f='auto'
    l=50
    mlflow.log_param("max_depth",d)
    mlflow.log_param("max_features",f)
    mlflow.log_param("max_leaf_nodes",l)
    dt_regressor = DecisionTreeRegressor(max_depth=d,max_features=f,max_leaf_nodes=l)
    dt_regressor.fit(X_train_rescaled, y_train)
    y_test_pred = dt_regressor.predict(X_test_rescaled)
    MAE = metrics.mean_absolute_error(y_test, y_test_pred)
    mlflow.log_metric("Mean Absolute error",MAE)
    mlflow.sklearn.log_model(dt_regressor, artifact_path="models")
    mlflow.log_artifact("Standard_Scaler.pkl")
    mlflow.log_artifact("Ordinal_Encoder.pkl")

# %% [markdown]
# # Training Support Vector Regressor

# %%
with mlflow.start_run():
    mlflow.set_tag("developer", "Ravi Teja")
    mlflow.set_tag("Algorithm", "SVR")
    # log the data for each run using log_param, log_metric, log_model
    mlflow.log_param("data-path","diamonds.csv")
    C = 0.1
    mlflow.log_param("C", C)
    sv_regressor = SVR(C=C)
    sv_regressor.fit(X_train_rescaled, y_train)
    y_test_pred = sv_regressor.predict(X_test_rescaled)
    MAE = metrics.mean_absolute_error(y_test, y_test_pred)
    mlflow.log_metric("Mean Absolute error",MAE)
    mlflow.sklearn.log_model(sv_regressor, artifact_path="models")
    mlflow.log_artifact("picklefiles/Standard_Scaler.pkl")
    mlflow.log_artifact("picklefiles/Ordinal_Encoder.pkl")

# %% [markdown]
# # Training Linear Regression

# %%
with mlflow.start_run():
    mlflow.set_tag("developer", "Ravi Teja")
    mlflow.set_tag("Algorithm", "Linear-Reg")
    # log the data for each run using log_param, log_metric, log_model
    mlflow.log_param("data-path", "diamonds.csv")
    C = 0.1
    mlflow.log_param("C", C)
    linear_regressor = LinearRegression()
    linear_regressor.fit(X_train_rescaled, y_train)
    y_test_pred = linear_regressor.predict(X_test_rescaled)
    MAE = metrics.mean_absolute_error(y_test, y_test_pred)
    mlflow.log_metric("Mean Absolute error",MAE)
    mlflow.sklearn.log_model(linear_regressor, artifact_path="models")
    mlflow.log_artifact("Standard_Scaler.pkl")
    mlflow.log_artifact("Ordinal_Encoder.pkl")

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Enabling automatic MLflow logging for scikit-learn runs
mlflow.sklearn.autolog(max_tuning_runs=None)

with mlflow.start_run():
    tuned_parameters = [{'n_neighbors':[i for i in range(1, 51)], 'p':[1, 2]}]

    reg = GridSearchCV(
        estimator=KNeighborsRegressor(), 
        param_grid=tuned_parameters, 
        scoring='neg_mean_absolute_error',
        cv=5,
        return_train_score=True,
        verbose=1
    )
    reg.fit(X_train_rescaled, y_train)
    
    # Disabling autologging
    mlflow.sklearn.autolog(disable=True)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
